# %% [markdown]
# ### Imports & Options

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import random
import pickle

# %%
# import numpy as np
from PIL import Image
from rtree import index

# %%
import sys
sys.path.append("../src")

# %%
from stippling import Stipple

# %% [markdown]
# ### Scratchpad

# %%
filename = "../images/ame.png"
stippling = Stipple(original_filename = filename)
# stippling = Stipple(greyscale_filename = "../images/ame_greyscale.png")
stippling.img
# Out:
# <PIL.Image.Image image mode=LA size=512x512 at 0x10696D128>

# %%
# num_dots = 2000
# stippling.place_dots(num_dots)
# stippling.redistribute_dots(num_dots*10)
# stippling.draw_points()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1027B3D68>

# %%
num_dots = 2500
stippling.place_dots(num_dots)
stippling.draw_points(save_image=True)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x10696D550>

# %%
for _ in range(10):
    stippling.redistribute_dots(num_dots)
    stippling.draw_points(save_image=True)
