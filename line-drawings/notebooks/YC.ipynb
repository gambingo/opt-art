# %% [markdown]
# ### Imports & Options

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import random
import pickle

# %%
# import numpy as np
from PIL import Image
from rtree import index

# %%
from stippling import Stipple

# %% [markdown]
# ### Scratchpad

# %%
filename = "yc_greyscale.png"
# img = Image.open(greyscale_filename = filename)
# width, height = img.size

# %%
# stippling = Stipple(greyscale_filename=filename)
stippling = Stipple(original_filename = "yc.jpeg")
stippling.img
# Out:
# <PIL.Image.Image image mode=LA size=512x512 at 0x1119C6F60>

# %%
num_dots = 2000
stippling.place_dots(num_dots)
stippling.redistribute_dots(num_dots*10)
stippling.draw_points()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x10740FE10>

# %%
# pickle.dump(stippling, open("yc_2000_dots.pkl", "wb"))
